# %% [markdown]
# # EXP0 : Introduction to python

# %%
#viraj
print("viraj deshmukh")
# Out:
# viraj deshmukh

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print(2)
print([1,2,5])
print("viraj deshmukh")
# Out:
# 2
# [1, 2, 5]
# viraj deshmukh

# %%
x=2
y=[1,2,5]
z='viraj deshmukh'
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# viraj deshmukh
