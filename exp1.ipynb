# %% [markdown]
# <a href="https://colab.research.google.com/github/dviraj053-rgb/praczero/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exp 1 ; Introduction to python
#viraj

# %%
print ("apple")
print ("cherry")
print ("orange")
# Out:
# apple
# cherry
# orange

# %%
x,y,z="apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
x,y,w,z=2,2.5,"viraj",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# data types

# %%
a,b=10,5
print("sum =",a+b)
print("difference =",a-b)
print("product =",a*b)
print("division =",a/b)
print("exponent =",a**b)
# Out:
# sum = 15
# difference = 5
# product = 50
# division = 2.0
# exponent = 100000

# %% [markdown]
# sum,sub,mult,div,exponent

# %%
a,b=10,5
print("sum =",a+b , "difference =",a-b , "product =",a*b , "division =",a/b , "exponent =",a**b , "\n")
# Out:
# sum = 15 difference = 5 product = 50 division = 2.0 exponent = 100000

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("\n""sum=",a+b,"\n""sub=",a-b,"\n""mult=",a*b,"\n""div=",a/b,"\n""expo=",a**b,)
# Out:
# enter the value of a=5
# enter the value of b=10
#
# sum= 15
# sub= -5
# mult= 50
# div= 0.5
# expo= 9765625

# %%
import math
r=float(input("ente the radius of circle="))
area=math.pi*r**2
print(area)
# Out:
# ente the radius of circle=1
# 3.141592653589793

# %%
import math
math.log10(10)
# Out:
# 1.0

# %%
a,b=10,5
if a>b:
  print("b is less than a")
  else:
    print("b is grater than a")
